# %%
import joblib
from pathlib import Path

# Cargar artefactos desde la carpeta artifacts y mostrar rutas
artifacts_dir = Path('../artifacts')
vec_path = artifacts_dir / 'vectorizer.pkl'
model_path = artifacts_dir / 'model.pkl'

if vec_path.exists():
    vectorizer = joblib.load(vec_path)
    print(f"Vectorizer cargado desde: {vec_path.resolve()}")
else:
    print(f"No se encontró {vec_path.resolve()}. Ejecuta el notebook 01 para crear y guardar el vectorizer.")

if model_path.exists():
    clf = joblib.load(model_path)
    print(f"Modelo cargado desde: {model_path.resolve()}")
else:
    print(f"No se encontró {model_path.resolve()}. Ejecuta el notebook 02 para entrenar y guardar el modelo.")
# Out:
# Vectorizer cargado desde: C:\Users\ddani\Desktop\Aplicación de Machine Learning con Interfaz Web\Toxic_comment_classifier\artifacts\vectorizer.pkl
# Modelo cargado desde: C:\Users\ddani\Desktop\Aplicación de Machine Learning con Interfaz Web\Toxic_comment_classifier\artifacts\model.pkl
